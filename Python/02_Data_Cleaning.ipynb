# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Data/raw/games.csv")

# %%
steam = df.copy()

# %%
steam.columns = ['Name', 'Release date', 'Estimated owners', 'Peak CCU',
       'Required age', 'Price', 'Discount', 'DLC count', 'About the game',
       'Supported languages', 'Full audio languages', 'Reviews',
       'Header image', 'Website', 'Support url', 'Support email', 'Windows',
       'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
       'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
       'Notes', 'Average playtime forever', 'Average playtime two weeks',
       'Median playtime forever', 'Median playtime two weeks', 'Developers',
       'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies']

# %%
steam.drop_duplicates(inplace=True)

# %%
steam["Release date"] = pd.to_datetime(
    steam["Release date"],
    format="mixed",
    errors="coerce"
)

# %%
steam.dropna(subset=["Name"], inplace=True)

# %%
columns_to_drop = [
    "Movies",
    "Score rank",
    "Metacritic url",
    "Reviews",
    "Notes",
    "Website",
    "Support url",
    "Support email",
    "Header image",
    "Screenshots"
]

steam.drop(columns=columns_to_drop, inplace=True)

# %%
steam["Total Reviews"] = (
    steam["Positive"] +
    steam["Negative"]
)

# %%
steam["Review Score %"] = np.where(
    steam["Total Reviews"] == 0,
    0,
    (steam["Positive"] / steam["Total Reviews"]) * 100
)

# %%
steam["Release Year"] = (
    steam["Release date"].dt.year
)

# %%
steam["Release Month"] = (
    steam["Release date"].dt.month_name()
)

# %%
def categorize_price(price):

    if price == 0:
        return "Free"

    elif price < 10:
        return "Budget"

    elif price < 30:
        return "Standard"

    elif price < 60:
        return "Premium"

    else:
        return "Expensive"

steam["Price Category"] = (
    steam["Price"].apply(categorize_price)
)

# %%
steam.to_csv("../Data/Cleaned/steam.csv")

# %%
steam.sample(5)
# Out:
#                     Name Release date Estimated owners  Peak CCU  \
# 1690     Space Empires V   2006-10-16  100000 - 200000         4
# 3946430  Robot-Mail Rush   2025-09-13            0 - 0         0
# 2877240   Miko in Maguma   2024-04-26            0 - 0         0
# 3058520  Goddess Connect   2024-07-24        0 - 20000         0
# 1443950        Last Hope   2021-09-29        0 - 20000         0
#
#          Required age  Price  Discount  DLC count  \
# 1690                0   2.99        80          0
# 3946430             0   0.55         0          0
# 2877240             0   0.00         0          0
# 3058520             0   0.00         0          0
# 1443950             0   0.49        51          0
#
#                                             About the game  \
# 1690     Space Empires V is the latest edition in the S...
# 3946430  Become a postman in a world of robots! Take on...
# 2877240  I fell into magma again today. Anyway, I'm goi...
# 3058520  Dive into a world of never-ending adventure in...
# 1443950  Last Hope is a combat-focused survival game wh...
#
#                            Supported languages  ...               Developers  \
# 1690                               ['English']  ...    Malfador Machinations
# 3946430                 ['English', 'Russian']  ...  Green Goose Corporation
# 2877240  ['English', 'Japanese', 'Indonesian']  ...               frog blend
# 3058520                            ['English']  ...     Game Hollywood Games
# 1443950                            ['English']  ...                    VuVuu
#
#                       Publishers  \
# 1690              Strategy First
# 3946430  Green Goose Corporation
# 2877240               holo Indie
# 3058520     Game Hollywood Games
# 1443950                    VuVuu
#
#                                                 Categories  \
# 1690             Single-player,Multi-player,Family Sharing
# 3946430  Single-player,Steam Achievements,Keyboard Only...
# 2877240                                      Single-player
# 3058520  Single-player,In-App Purchases,Remote Play on ...
# 1443950                       Single-player,Family Sharing
#
#                                          Genres  \
# 1690                                   Strategy
# 3946430                            Casual,Indie
# 2877240                      Indie,Free To Play
# 3058520                        RPG,Free To Play
# 1443950  Action,Adventure,Casual,Indie,Strategy
#
#                                                       Tags  Total Reviews  \
# 1690     Strategy,4X,Space,Turn-Based,Sci-fi,Singleplay...            453
# 3946430                                                NaN              0
# 2877240                                                NaN              0
# 3058520                                                NaN              0
# 1443950  Adventure,Casual,Strategy,Action-Adventure,Exp...             14
#
#          Review Score %  Release Year  Release Month  Price Category
# 1690           72.18543          2006        October          Budget
# 3946430         0.00000          2025      September          Budget
# 2877240         0.00000          2024          April            Free
# 3058520         0.00000          2024           July            Free
# 1443950        50.00000          2021      September          Budget
#
# [5 rows x 34 columns]
